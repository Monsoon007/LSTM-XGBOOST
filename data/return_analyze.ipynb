# %%
from get_data import get_return_data
from model.LSTM_base_model import T_values, train_start_date, train_end_date

import pandas as pd

# 创建一个空的DataFrame
df = pd.DataFrame()

# 遍历T_values并获取回报数据，将其添加到DataFrame中
for T in T_values:
    df[T] = get_return_data('SHSE.510300', train_start_date, train_end_date, T).iloc[:,-1]
    
# 显示DataFrame
df
# Out:
#                     1           2           3           4           5   \
# bob
# 2013-07-01  0.00312919  0.00044703  0.00268216  0.00290568 -0.00312919
# 2013-07-02 -0.00222816  0.00245098  0.00282234 -0.00467914 -0.00418895
# 2013-07-03  0.00714605  0.00535954 -0.00550841 -0.00468959  0.00169719
# 2013-07-04  0.00354767 -0.01175166 -0.00857354  0.00033259  0.01028825
# 2013-07-05 -0.02695537 -0.01458241 -0.00073649  0.01193106  0.00433053
# ...                ...         ...         ...         ...         ...
# 2020-06-23  0.00872093  0.00000000  0.00403747  0.00872093  0.01172481
# 2020-06-24 -0.00864553  0.00168108  0.00864553  0.01236792  0.01407301
# 2020-06-29  0.01211240  0.01744186  0.01954134  0.01992490  0.03178295
# 2020-06-30  0.02249880  0.02297750  0.02225945  0.03626137  0.02671135
# 2020-07-01  0.02294007  0.02165262  0.03995006  0.02715356  0.02462547
#
#                     6           7           8           9           10  ...  \
# ...

# %%
df.describe()
# Out:
#                   1              2              3              4   \
# count  1707.00000000  1707.00000000  1707.00000000  1707.00000000
# mean      0.00051792     0.00052685     0.00053754     0.00053951
# std       0.01579753     0.01134371     0.00906579     0.00772731
# min      -0.10005198    -0.08855172    -0.07269550    -0.05951469
# 25%      -0.00596684    -0.00449222    -0.00352476    -0.00311410
# 50%       0.00027902     0.00043054     0.00065488     0.00058428
# 75%       0.00712882     0.00585498     0.00509323     0.00433157
# max       0.09991337     0.10482241     0.07421311     0.04988449
#
#                   5              6              7              8   \
# count  1707.00000000  1707.00000000  1707.00000000  1707.00000000
# mean      0.00054427     0.00055283     0.00055461     0.00055633
# std       0.00691108     0.00633334     0.00581783     0.00542588
# min      -0.04410766    -0.04567210    -0.03897054    -0.03432028
# ...

# %%
# 取出df的各列75%分位数，绘图
df.quantile(0.75).plot(kind='bar')
# Out:
# <Axes: >
